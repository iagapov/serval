# %%
import sys
sys.path.append('/Users/ia/workspace/ocelot/')
import ocelot
from ocelot import *
# Out:
# math_op.py: module Numba is not installed. Install it if you want speed up correlation calculations
# [INFO    ] : : csr.py: module NUMBA is not installed. Install it to speed up calculation
# [INFO    ] csr.py: module NUMBA is not installed. Install it to speed up calculation
# [INFO    ] csr.py: module PYFFTW is not installed. Install it to speed up calculation.
# [INFO    ] csr.py: module NUMEXPR is not installed. Install it to speed up calculation
# [INFO    ] wake3D.py: module NUMBA is not installed. Install it to speed up calculation
# initializing ocelot...
# import: module NUMBA is not installed. Install it to speed up calculation
# import: module PYFFTW is not installed. Install it to speed up calculation
# import: module NUMEXPR is not installed. Install it to speed up calculation

# %%
DL1A_1 = SBend( l=0.355237230523, angle=0.0060061926, e1=0.0079280963, e2=-0.0019219037)
DL1A_2 = SBend( l=0.355236880485, angle=0.003525, e1=0.0019219037, e2=0.0016030963)
DL1A_3 = SBend( l=0.355236802481, angle=0.002675, e1=-0.0016030963, e2=0.0042780963)
DL1A_4 = SBend( l=0.355236761841, angle=0.0021, e1=-0.0042780963, e2=0.0063780963)
DL1A_5 = SBend( l=0.355236732127, angle=0.00155, e1=-0.0063780963, e2=0.0079280963)
DL1E_1 = SBend( l=0.355236732127, angle=0.00155, e1=0.0079280963, e2=-0.0063780963)
DL1E_2 = SBend( l=0.355236761841, angle=0.0021, e1=0.0063780963, e2=-0.0042780963)
DL1E_3 = SBend( l=0.355236802481, angle=0.002675, e1=0.0042780963, e2=-0.0016030963)
DL1E_4 = SBend( l=0.355236880485, angle=0.003525, e1=0.0016030963, e2=0.0019219037)
DL1E_5 = SBend( l=0.355237230523, angle=0.0060061926, e1=-0.0019219037, e2=0.0079280963)
DL2B_1 = SBend( l=0.355236732127, angle=0.00155, e1=0.0073530963, e2=-0.0058030963)
DL2B_2 = SBend( l=0.355236761841, angle=0.0021, e1=0.0058030963, e2=-0.0037030963)
DL2B_3 = SBend( l=0.355236802481, angle=0.002675, e1=0.0037030963, e2=-0.0010280963)
DL2B_4 = SBend( l=0.355236880485, angle=0.003525, e1=0.0010280963, e2=0.0024969037)
DL2B_5 = SBend( l=0.355237045626, angle=0.0048561926, e1=-0.0024969037, e2=0.0073530963)
DL2D_1 = SBend( l=0.355237045626, angle=0.0048561926, e1=0.0073530963, e2=-0.0024969037)
DL2D_2 = SBend( l=0.355236880485, angle=0.003525, e1=0.0024969037, e2=0.0010280963)
DL2D_3 = SBend( l=0.355236802481, angle=0.002675, e1=-0.0010280963, e2=0.0037030963)
DL2D_4 = SBend( l=0.355236761841, angle=0.0021, e1=-0.0037030963, e2=0.0058030963)
DL2D_5 = SBend( l=0.355236732127, angle=0.00155, e1=-0.0058030963, e2=0.0073530963)
DQ1 = SBend( l=1.02124244444, angle=0.0146, e1=0.0073, e2=0.0073, k1=-1.918095891915395)
DQ2C_1 = SBend( l=0.397357504068, angle=0.003925, e1=0.003925, e2=0, k1=-1.367824957723682)
DQ2C_2 = SBend( l=0.397357504068, angle=0.003925, e1=0, e2=0.003925, k1=-1.367824957723682)
QD2 = Quadrupole( l=0.210598936443, k1=-3.20906924476761)
QD3 = Quadrupole( l=0.160929375961, k1=-2.2670788780813730)
QD5 = Quadrupole( l=0.210598936443, k1=-2.969358116194729)
QF1 = Quadrupole( l=0.293050406843, k1=2.782527811390676)
QF4A = Quadrupole( l=0.210598936443, k1=2.622398813720869)
QF4B = Quadrupole( l=0.210598936443, k1=2.622398813720869)
QF6 = Quadrupole( l=0.38543578934, k1=4.618095694247654)
QF8 = Quadrupole( l=0.480801345465, k1=4.391906684657389)
SD1A= Sextupole( l=0.1649029408, k2=-376.2345951364623)
SD1B= Sextupole( l=0.1649029408, k2=-354.1496244019682)
SD1D= Sextupole( l=0.1649029408, k2=-354.1496244019682)
SD1E= Sextupole( l=0.1649029408, k2=-376.2345951364623)
SF2AH= Sextupole( l=0.0993391209638, k2=349.8749185808225)
SF2EH= Sextupole( l=0.0993391209638, k2=349.8749185808225)
SH1A= Sextupole( l=0.0993391209638, k2=0)
SH2B= Sextupole( l=0.0993391209638, k2=0)
SH3E= Sextupole( l=0.0993391209638, k2=0)
OF1B= Octupole( l=0.0894052088675, k3=-44361.11935947544)
OF1D= Octupole( l=0.0894052088675, k3=-44361.11935947544)
DR_01= Drift( l=2.63387745324)
DR_02= Drift( l=0.050662951691)
DR_03= Drift( l=0.10927303306)
DR_04= Drift( l=0.228479978217)
DR_05= Drift( l=0.046689386853)
DR_07= Drift( l=0.07450434072290001)
DR_08= Drift( l=0.5412526124730001)
DR_09= Drift( l=0.0556299077398)
DR_12= Drift( l=0.0596034737704)
DR_14= Drift( l=0.392243927749)
DR_17= Drift( l=0.09337877370600001)
DR_19= Drift( l=0.0894052088675)
DR_21= Drift( l=0.1649029408)
DR_22= Drift( l=0.0367554747566)
BPM_01= Monitor()
BPM_02= Monitor()
BPM_03= Monitor()
BPM_04= Monitor()
BPM_05= Monitor()
BPM_06= Monitor()
BPM_07= Monitor()
BPM_08= Monitor()
BPM_09= Monitor()
BPM_10= Monitor()
CELLCENTER= Marker()
DISPBUMPCENTER= Marker()
DLMARKER= Marker()
IDMARKER= Marker()
SF2AMARKER= Marker()
SF2EMARKER= Marker()


# Line Definition

RING =(DR_01,BPM_01,DR_02,QF1,DR_03,SH1A,DR_04,QD2,DR_05,DLMARKER,
DL1A_1,DL1A_2,DL1A_3,DL1A_4,DL1A_5,DR_05,QD3,DR_07,SD1A,DR_08,BPM_02,DR_09,
QF4A,DR_07,DISPBUMPCENTER,SF2AH,SF2AMARKER,SF2AH,DR_07,QF4B,DR_12,OF1B,DR_09,
BPM_03,DR_14,SD1B,DR_07,QD5,DR_05,DL2B_1,DL2B_2,DL2B_3,DL2B_4,DL2B_5,DR_17,BPM_04,
DR_09,QF6,DR_19,DQ1,DR_19,QF8,DR_21,SH2B,DR_22,BPM_05,DR_09,DQ2C_1,CELLCENTER,
DQ2C_2,DR_09,BPM_06,DR_22,SH2B,DR_21,QF8,DR_19,DQ1,DR_19,QF6,DR_09,BPM_07,
DR_17,DL2D_1,DL2D_2,DL2D_3,DL2D_4,DL2D_5,DR_05,QD5R,DR_07,SD1D,DR_14,BPM_08,
DR_09,OF1D,DR_12,QF4B,DR_07,DISPBUMPCENTER,SF2EH,SF2EMARKER,SF2EH,DR_07,QF4A,
DR_09,BPM_09,DR_08,SD1E,DR_07,QD3,DR_05,DL1E_1,DL1E_2,DL1E_3,DL1E_4,DL1E_5,DLMARKER,
DR_05,QD2,DR_04,SH3E,DR_03,QF1,DR_02,BPM_10,DR_01,IDMARKER)

# %%
lat = MagneticLattice(RING)
tws = twiss(lat, Twiss())

from pylab import *

plt.plot([t.s for t in tws], [t.beta_x for t in  tws])
plt.plot([t.s for t in tws], [t.beta_y for t in  tws])

# %%
ocelog = logging.getLogger('ocelot')
ocelog.setLevel(logging.ERROR)

# %%
n_train = 50000

x_train = np.zeros([n_train,2])  
y_train = np.zeros([n_train,1])


#DQ1 = SBend( l=1.02124244444, angle=0.0146, e1=0.0073, e2=0.0073, k1=-1.918095891915395)
#DQ2C_1 = SBend( l=0.397357504068, angle=0.003925, e1=0.003925, e2=0, k1=-1.367824957723682)
#DQ2C_2 = SBend( l=0.397357504068, angle=0.003925, e1=0, e2=0.003925, k1=-1.367824957723682)
#QD2 = Quadrupole( l=0.210598936443, k1=-3.20906924476761)
#QD3 = Quadrupole( l=0.160929375961, k1=-2.2670788780813730)
#QD5 = Quadrupole( l=0.210598936443, k1=-2.969358116194729)
#QF1 = Quadrupole( l=0.293050406843, k1=2.782527811390676)
#QF4A = Quadrupole( l=0.210598936443, k1=2.622398813720869)
#QF4B = Quadrupole( l=0.210598936443, k1=2.622398813720869)
#QF6 = Quadrupole( l=0.38543578934, k1=4.618095694247654)
#QF8 = Quadrupole( l=0.480801345465, k1=4.391906684657389)




for i in range(n_train):
    QF1.k1 = 0. + 6.*np.random.rand()
    QD2.k1 = -0. -6.*np.random.rand()
    
    x_train[i,0] = QF1.k1
    x_train[i,1] = QD2.k1
  
    lat.update_transfer_maps()
    tws = twiss(lat, Twiss())
    if tws is None:
        y_train[i,0] = 0
    else:
        y_train[i,0] = 1

# %%
x1 = []
x2 = []
x1o = []
x2o = []
for i in range(n_train):
    if y_train[i] == 1:
        x1.append(x_train[i,0])
        x2.append(x_train[i,1])
    else:
        x1o.append(x_train[i,0])
        x2o.append(x_train[i,1])

plt.scatter(x1o,x2o,color='yellow')
plt.scatter(x1,x2, color='blue')





plt.show()

# %%
import numpy as np
import keras
from keras.datasets import reuters
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.preprocessing.text import Tokenizer

#fixing a duplicate openmp dylib on mac???
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

model = Sequential() 
model.add(Dense(1000, input_dim=2, activation='relu')) 
#model.add(Dropout(0.5))
model.add(Dense(1000, activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid')) 
model.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])
model.fit(x_train,y_train, epochs=19, batch_size=4)
# Out:
# Epoch 1/19
# 50000/50000 [==============================] - 77s 2ms/step - loss: 0.1695 - acc: 0.9425
# Epoch 2/19
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.1413 - acc: 0.9427
# Epoch 3/19
# 50000/50000 [==============================] - 70s 1ms/step - loss: 0.1292 - acc: 0.9437
# Epoch 4/19
# 50000/50000 [==============================] - 72s 1ms/step - loss: 0.1228 - acc: 0.9482
# Epoch 5/19
# 50000/50000 [==============================] - 72s 1ms/step - loss: 0.1210 - acc: 0.9492
# Epoch 6/19
# 50000/50000 [==============================] - 71s 1ms/step - loss: 0.1193 - acc: 0.9503
# Epoch 7/19
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.1176 - acc: 0.9504
# Epoch 8/19
# 50000/50000 [==============================] - 73s 1ms/step - loss: 0.1164 - acc: 0.9502
# Epoch 9/19
# 50000/50000 [==============================] - 75s 2ms/step - loss: 0.1153 - acc: 0.9504
# Epoch 10/19
# ...

# %%
n_test = 1000

x_test = np.zeros([n_test,2])  
y_test = np.zeros([n_test,1])


for i in range(n_test):
    QF1.k1 = 5*np.random.rand()
    QD2.k1 = -5*np.random.rand()
    
    x_test[i,0] = QF1.k1
    x_test[i,1] = QD2.k1
    lat.update_transfer_maps()
    tws = twiss(lat, Twiss())
    if tws is None:
        y_test[i,0] = 0
    else:
        y_test[i,0] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-afc62f7458a0> in <module>
#      12     x_test[i,1] = QD2.k1
#      13     lat.update_transfer_maps()
# ---> 14     tws = twiss(lat, Twiss())
#      15     if tws is None:
#      16         y_test[i,0] = 0
#
# ~/workspace/ocelot/ocelot/cpbd/optics.py in twiss(lattice, tws0, nPoints)
#    1030     if tws0.__class__ == Twiss:
#    1031         if tws0.beta_x == 0 or tws0.beta_y == 0:
# -> 1032             R = lattice_transfer_map(lattice, tws0.E)
#    1033             tws0 = periodic_twiss(tws0, R)
#    1034             if tws0 == None:
#
# ~/workspace/ocelot/ocelot/cpbd/optics.py in lattice_transfer_map(lattice, energy)
#     923                         t1 = 0.
#     924                         for l in range(6):
# --> 925                             t1 += Rb[i, l] * Ta[l, j, k]
# ...

# %%
X, Y = np.meshgrid(np.linspace(0,7,100),np.linspace(-7,0,100))
Z = 0. * X
for i in range(100):
    for j in range(100):
        p = np.array([[X[i,j],Y[i,j]]])
        #print(p)
        Z[i,j] =model.predict(p) #treat xv[i,j], yv[i,j]

plt.imshow(Z[::-1,:])
plt.show()

# %%
x1 = []
x2 = []
for i in range(n_test):
    if y_test[i] == 1:
        x1.append(x_test[i,0])
        x2.append(x_test[i,1])
        
plt.scatter(x1,x2)


x1 = []
x2 = []

for i in range(100):
    for j in range(100):
        if Z[i,j] > 0.1:
            x1.append(X[i,j])
            x2.append(Y[i,j])

plt.scatter(x1,x2, alpha=0.1)

plt.show()
